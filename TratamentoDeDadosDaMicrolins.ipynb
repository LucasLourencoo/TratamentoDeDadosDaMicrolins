# %%
#Feito pelo Google Colab

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
from google.colab import files
uploaded = files.upload()

# %%
controle_df = pd.read_excel('alunosativos.xlsx')
display(controle_df)
# Out:
#                                   Aluno  Qtd. Formações Ativas  \
# 0            08/08/2022 [1 registro(s)]                    NaN
# 1    Victória Carolina Monteiro Magarão                    1.0
# 2            05/08/2022 [2 registro(s)]                    NaN
# 3               Gabriela Abreu da Silva                    1.0
# 4             Gabriela da Silva Prestes                    0.0
# ..                                  ...                    ...
# 162   José Lucas Levi Rodrigues Martins                    1.0
# 163          14/02/2022 [3 registro(s)]                    NaN
# 164                 Davi Franco da Rosa                    0.0
# 165           Marcela Serejo C. Alberti                    0.0
# 166           Tatiana Oliveira da Silva                    1.0
#
#                    Formações Ativas  \
# 0                               NaN
# 1    26810 - CAPACITAÇÃO - DINÂMICA
# 2                               NaN
# 3    26810 - CAPACITAÇÃO - DINÂMICA
# ...

# %%
controle_df = controle_df[['Aluno','Cursos Ativos']]
controle_df = controle_df.dropna(how='any')
controle_df['Aluno'] = [each.title() for each in controle_df['Aluno']]
controle_df = controle_df.sort_values(by='Aluno')
display(controle_df)
# Out:
#                                    Aluno  \
# 22           Adriano Rodrigues De Araujo
# 159                  Alex Gomes Da Silva
# 78                   Alex Gomes Da Silva
# 13   Alexandra De Castro Barbosa Almeida
# 57        Amanda Vitória De Sousa Castro
# ..                                   ...
# 1     Victória Carolina Monteiro Magarão
# 127            Vinicios De Sousa Pereira
# 142        Willian Junior Da Silva Braga
# 70              Zenilda Gonçalves Avelar
# 9                 Ângela Alves Pardavila
#
#                                          Cursos Ativos
# 22   Microsoft Windows 10,Microsoft Word 2016,Micro...
# 159                               Microsoft Excel 2016
# 78                               Matemática Financeira
# 13                                Microsoft Excel 2016
# 57   Microsoft Windows 10,Microsoft Word 2016,Micro...
# ..                                                 ...
# 1    Microsoft Word 2016,Microsoft PowerPoint 2016,...
# ...

# %%
controle_df.to_csv('Controle_dos_alunos.csv', index=False, sep=';', encoding='latin')

# %%
files.download('Controle_dos_alunos.csv')
